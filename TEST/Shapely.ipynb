# %% [markdown]
# # Shapely Test

# %%
from shapely.geometry import Polygon
import matplotlib.pyplot as plt

# 2つの多角形を定義
polygon1 = Polygon([(0, 0), (2, 0), (2, 2), (0, 2)])
polygon2 = Polygon([(1, 1), (3, 1), (3, 3), (1, 3)])

# 接触判定
touches = polygon1.intersects(polygon2)
print(f"Polygons intersect: {touches}")

# 描画
x1, y1 = polygon1.exterior.xy
x2, y2 = polygon2.exterior.xy

plt.plot(x1, y1, label='Polygon 1')
plt.plot(x2, y2, label='Polygon 2')
plt.fill(x1, y1, alpha=0.5, fc='r', ec='none')
plt.fill(x2, y2, alpha=0.5, fc='b', ec='none')

plt.legend()
plt.show()
# Out:
# Polygons intersect: True

# %% [markdown]
# ## 線接触は接触判定

# %%
from shapely.geometry import Polygon
import matplotlib.pyplot as plt

# 2つの多角形を定義
polygon1 = Polygon([(0, 0), (2, 0), (2, 2), (0, 2)])
polygon2 = Polygon([(0, 2), (2, 2), (2, 4), (0, 4)])

# 接触判定
touches = polygon1.intersects(polygon2)
print(f"Polygons intersect: {touches}")

# 描画
x1, y1 = polygon1.exterior.xy
x2, y2 = polygon2.exterior.xy

plt.plot(x1, y1, label='Polygon 1')
plt.plot(x2, y2, label='Polygon 2')
plt.fill(x1, y1, alpha=0.5, fc='r', ec='none')
plt.fill(x2, y2, alpha=0.5, fc='b', ec='none')

plt.legend()
plt.show()
# Out:
# Polygons intersect: True

# %% [markdown]
# ## 点接触は接触判定

# %%
from shapely.geometry import Polygon
import matplotlib.pyplot as plt

# 2つの多角形を定義
polygon1 = Polygon([(0 ,0), (2, 0), (2, 2), (0, 2)])
polygon2 = Polygon([(2, 2), (4, 2), (4, 4), (2, 4)])

# 接触判定
touches = polygon1.intersects(polygon2)
print(f"Polygons intersect: {touches}")

# 描画
x1, y1 = polygon1.exterior.xy
x2, y2 = polygon2.exterior.xy

plt.plot(x1, y1, label='Polygon 1')
plt.plot(x2, y2, label='Polygon 2')
plt.fill(x1, y1, alpha=0.5, fc='r', ec='none')
plt.fill(x2, y2, alpha=0.5, fc='b', ec='none')

plt.legend()
plt.show()
# Out:
# Polygons intersect: True
